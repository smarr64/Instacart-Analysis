# %% [markdown]
# # Table of Contents
# ## 1. Import Data and Checks
# ## 2. Create Customer Loyalty Flag
# ## 3. Create Flag for Price Ranges
# ## 4. Create Flag for High and Low Spenders
# ## 5. Export Data

# %% [markdown]
# # 1. Import Data and Checks

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# create path
path = r'C:\Users\18602\Documents\Data Analytics\Data Immersion\Month 4\Instacart Basket Analysis'

# %%
# import data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_large.pkl'))

# %%
# rename for easy of coding
df = ords_prods_merge

# %%
# check shape
df.shape
# Out:
# (32641279, 20)

# %%
#find column names
df.columns
# Out:
# Index(['Unnamed: 0_x', 'order_id', 'user_id', 'order_number',
#        'order_day_of_week', 'order_hour_of_day', 'days_since_prior_order',
#        'product_id', 'add_to_cart_order', 'reordered', '_merge',
#        'Unnamed: 0_y', 'product_name', 'aisle_id', 'department_id', 'prices',
#        'price_range_loc', 'busiest_day', 'busiest_days',
#        'busiest_period_of_day'],
#       dtype='object')

# %%
# chech output
df.head()
# Out:
#    Unnamed: 0_x   order_id  user_id  order_number  order_day_of_week  \
# 0           0.0  2539329.0      1.0           1.0                2.0
# 1           1.0  2398795.0      1.0           2.0                3.0
# 2           2.0   473747.0      1.0           3.0                3.0
# 3           3.0  2254736.0      1.0           4.0                4.0
# 4           4.0   431534.0      1.0           5.0                4.0
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                8.0                     NaN       196.0                1.0
# 1                7.0                    15.0       196.0                1.0
# 2               12.0                    21.0       196.0                1.0
# 3                7.0                    29.0       196.0                1.0
# 4               15.0                    28.0       196.0                1.0
#
#    reordered _merge  Unnamed: 0_y product_name  aisle_id  department_id  \
# 0        0.0   both         195.0         Soda      77.0            7.0
# 1        1.0   both         195.0         Soda      77.0            7.0
# 2        1.0   both         195.0         Soda      77.0            7.0
# 3        1.0   both         195.0         Soda      77.0            7.0
# 4        1.0   both         195.0         Soda      77.0            7.0
#
#    prices    price_range_loc     busiest_day     busiest_days  \
# 0     9.0  Mid=range product  Regularly busy   Regularly busy
# 1     9.0  Mid=range product  Regularly busy  Least busy days
# 2     9.0  Mid=range product  Regularly busy  Least busy days
# 3     9.0  Mid=range product      Least busy  Least busy days
# 4     9.0  Mid=range product      Least busy  Least busy days
#
#   busiest_period_of_day
# 0        Average Orders
# 1        Average Orders
# 2           Most Orders
# 3        Average Orders
# 4           Most Orders

# %%
# drop unnecessary column busiest day and unnamed columns

df = df.drop(columns=['busiest_day', 'Unnamed: 0_x', 'Unnamed: 0_y'])

# %% [markdown]
# # 2. Create Customer Loyalty Flag

# %%
# create average orders of department_id
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1.0              15.457838
# 2.0              17.277920
# 3.0              17.170395
# 4.0              17.811403
# 5.0              15.215751
# 6.0              16.439806
# 7.0              17.225802
# 8.0              15.340650
# 9.0              15.895474
# 10.0             20.197148
# 11.0             16.170638
# 12.0             15.887671
# 13.0             16.583536
# 14.0             16.773669
# 15.0             16.165037
# 16.0             17.665606
# 17.0             15.694469
# 18.0             19.310397
# 19.0             17.177343
# 20.0             16.473447
# 21.0             22.902379

# %% [markdown]
# The average number of orders per user is lower than in the partial data set in the visible data output

# %%
# create max_order column with groupby for loyalty flag

df['max_order'] = df.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# create loyalty flag parameters
df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# check loyalty counts
df['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    16381472
# Loyal customer      10679578
# New customer         5580218
# NaN                       11
# Name: loyalty_flag, dtype: int64

# %%
# check output of loyalty flag
df[['user_id', 'loyalty_flag', 'order_number', 'max_order']].head(20)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0       1.0  Regular customer           1.0       11.0
# 1       1.0  Regular customer           2.0       11.0
# 2       1.0  Regular customer           3.0       11.0
# 3       1.0  Regular customer           4.0       11.0
# 4       1.0  Regular customer           5.0       11.0
# 5       1.0  Regular customer           6.0       11.0
# 6       1.0  Regular customer           7.0       11.0
# 7       1.0  Regular customer           8.0       11.0
# 8       1.0  Regular customer           9.0       11.0
# 9       1.0  Regular customer          10.0       11.0
# 10     15.0  Regular customer          15.0       23.0
# 11     15.0  Regular customer          17.0       23.0
# 12     15.0  Regular customer          18.0       23.0
# 13     15.0  Regular customer          21.0       23.0
# 14     15.0  Regular customer          22.0       23.0
# 15     19.0      New customer           2.0       10.0
# 16     19.0      New customer           5.0       10.0
# 17     19.0      New customer           7.0       10.0
# 18     21.0  Regular customer          10.0       34.0
# 19     31.0  Regular customer          10.0       21.0

# %%
# check average price of types of customer
df.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.377144  1.0  99999.0
# New customer      13.208437  1.0  99999.0
# Regular customer  12.616225  1.0  99999.0

# %% [markdown]
# #The average prices seem to be slightly higher in New Customers than in Regular and Loyal customers.
# The min and max don't entirely make sense. No is priced is 99999 so I'm going to assume that my data needs to be cleaned or that the min and max are not aggregating price correctly.

# %% [markdown]
# # 3. Create Flag for Price Ranges

# %%
# create df to check prices
df2 = df['prices']

# %%
# check for descriptive statistics of price
df2.describe()
# Out:
# count    3.240487e+07
# mean     1.198022e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %% [markdown]
# Based on this analysis I'm going to conclude some of the pricing is innacurate. Not sure how to drop or exclude those specific rows but we are going to assume it is skewing our results a little high but doing so evenly to all three categories.

# %%
# eliminate maximum rows
pd.options.display.max_rows = None

# %%
#check value counts

df2.value_counts()
# Out:
# 12.3       624261
# 10.3       510496
# 4.0        447272
# 6.3        438467
# 1.3        425691
# 7.3        411924
# 8.2        404015
# 1.4        392209
# 6.7        379126
# 4.5        367223
# 4.4        357026
# 6.8        354169
# 7.9        342988
# 14.3       334812
# 13.2       333183
# 5.7        323997
# 1.8        321185
# 9.1        320783
# 4.9        318220
# 8.8        318091
# 3.8        315426
# 6.9        314196
# 14.0       311640
# 12.8       309727
# 11.4       303015
# 3.6        300127
# 1.6        299352
# 2.0        286259
# 11.8       284476
# 5.3        284243
# 7.0        282884
# 14.7       279291
# 6.5        278357
# 8.3        276230
# 4.1        268269
# 2.9        264700
# 1.2        256258
# 8.6        254009
# 3.2        253782
# 5.2        251509
# 5.5        250136
# 3.1        249256
# 2.5        246421
# 4.2        245755
# 6.1        244209
# 1.1        242782
# 2.3        242051
# 5.8        241047
# 7.5        239261
# 14.1       238211
# 3.3        238041
# 10.5       237657
# 7.4        233506
# 9.0        228576
# 8.4        227493
# 5.0        225904
# 13.4       225843
# 11.5       225399
# 5.1        224797
# 3.4        223571
# 7.2        223120
# 3.5        222786
# 3.7        222159
# 4.7        221048
# 8.9        219412
# 9.6        216626
# 13.5       216276
# 1.7        213968
# 11.3       212926
# 3.9        212805
# 11.2       212323
# 2.6        211937
# 5.9        208900
# 5.4        206769
# 6.4        206468
# 11.7       206199
# 2.1        206004
# 6.6        204936
# 10.6       204804
# 2.7        199785
# 9.4        197179
# 6.0        196985
# 2.4        196042
# 9.8        194755
# 4.8        193853
# 3.0        192650
# 10.7       191705
# 7.7        190070
# 14.8       188844
# 12.2       188444
# 7.8        186923
# 5.6        183638
# 11.0       183505
# 9.2        182411
# 12.1       181986
# 13.7       181882
# 6.2        178656
# 8.1        176806
# 12.6       174427
# 13.3       173797
# 13.6       172962
# 11.1       169709
# 9.9        169251
# 9.3        168917
# 14.4       168272
# 8.7        166742
# 9.5        165789
# 10.2       165789
# 10.9       165607
# 12.0       164718
# 13.8       162616
# 4.3        162367
# 12.9       160860
# 2.2        160243
# 14.9       156433
# 1.9        156179
# 1.5        154527
# 2.8        153979
# 12.5       152781
# 8.0        151542
# 11.6       148742
# 13.9       145234
# 4.6        144069
# 7.1        140813
# 14.6       139880
# 10.1       139263
# 8.5        139244
# 10.4       133059
# 14.5       129540
# 10.0       127842
# 11.9       127349
# 12.7       124544
# 9.7        120777
# 14.2       119314
# 13.1       117047
# 1.0        115143
# 13.0       114503
# 7.6        113878
# 12.4        97866
# 15.0        97262
# 10.8        89927
# 21.1        33805
# 19.6        28383
# 22.3        19430
# 24.2        15891
# 18.2        14923
# 23.2        14866
# 25.0        13772
# 23.8        12585
# 21.6        10598
# 18.7        10503
# 23.1         9135
# 23.6         8458
# 18.6         8451
# 18.1         8027
# 21.3         7647
# 15.3         7495
# 24.7         7283
# 20.7         6568
# 19.3         6537
# 24.9         5781
# 20.0         5775
# 19.7         5538
# 19.4         5457
# 20.4         5351
# 22.1         5204
# 15.9         5078
# 16.9         4971
# 23.3         4803
# 16.8         4795
# 15.7         4551
# 14900.0      4429
# 18.8         4363
# 24.0         4327
# 17.3         4309
# 17.1         4231
# 16.6         4212
# 16.4         3892
# 22.9         3884
# 17.0         3836
# 20.1         3745
# 23.0         3265
# 18.5         3105
# 16.7         3105
# 19.1         2926
# 24.3         2889
# 19.0         2823
# 21.7         2553
# 16.5         2541
# 15.1         2422
# 15.5         2325
# 22.6         2275
# 24.5         2148
# 23.9         2074
# 17.7         2073
# 24.6         1962
# 23.5         1924
# 16.2         1823
# 18.4         1762
# 17.4         1721
# 16.1         1622
# 23.7         1346
# 22.4         1280
# 16.0         1272
# 22.0         1182
# 22.2         1178
# 15.4         1175
# 20.6         1167
# 18.0         1135
# 22.8         1089
# 20.9         1075
# 17.2         1001
# 19.2          981
# 17.8          981
# 24.1          978
# 20.5          945
# 19.9          887
# 20.8          852
# 15.8          772
# 22.5          706
# 99999.0       698
# 21.9          689
# 17.6          640
# 21.8          546
# 24.4          499
# 15.2          494
# 18.9          483
# 19.5          453
# 24.8          410
# 17.5          369
# 23.4          368
# 19.8          344
# 15.6          333
# 16.3          287
# 20.3          236
# 21.4          137
# 17.9          137
# 20.2          123
# 22.7           99
# 21.5           85
# 18.3           11
# 21.0            8
# Name: prices, dtype: int64

# %% [markdown]
# So this is interesting. Based on this analysis I can see we have two price points that are clearly incorrect. First is the 14900.0, which based on some context looks like it was supposed to be 14.9.
#
# The other one is that the 99999.0 has 698 results, which is still relatively small but not insignificant (.3% of the data).
#
# The solution would be to transform the 14900.0 and create a data frame without the 99999 average price. If we wanted to potentially use those products but couldn't find the correct information, I'd recommend inserting a mean into that slot that was based on a data frame that took out the 99999. This would lead to a lower average price point. However, for the purposes of this exercise I will leave that for another day.

# %%
#attempted to filter out all rows. Got error message.

df_filtered = (df.loc[df['prices'] < 14899])

# %% [markdown]
# I have decided to keep coding since my calculations will still work the same. If I get updated numbers I can use the same code to accomplish the task.

# %%
# make column for average price by user
df['average_order'] = df.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# check for new column
df.head()
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                2.0                8.0
# 1  2398795.0      1.0           2.0                3.0                7.0
# 2   473747.0      1.0           3.0                3.0               12.0
# 3  2254736.0      1.0           4.0                4.0                7.0
# 4   431534.0      1.0           5.0                4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN       196.0                1.0        0.0   both
# 1                    15.0       196.0                1.0        1.0   both
# 2                    21.0       196.0                1.0        1.0   both
# 3                    29.0       196.0                1.0        1.0   both
# 4                    28.0       196.0                1.0        1.0   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# 0         Soda      77.0            7.0     9.0  Mid=range product
# 1         Soda      77.0            7.0     9.0  Mid=range product
# 2         Soda      77.0            7.0     9.0  Mid=range product
# 3         Soda      77.0            7.0     9.0  Mid=range product
# 4         Soda      77.0            7.0     9.0  Mid=range product
#
#       busiest_days busiest_period_of_day  max_order      loyalty_flag  \
# 0   Regularly busy        Average Orders       11.0  Regular customer
# 1  Least busy days        Average Orders       11.0  Regular customer
# 2  Least busy days           Most Orders       11.0  Regular customer
# 3  Least busy days        Average Orders       11.0  Regular customer
# 4  Least busy days           Most Orders       11.0  Regular customer
#
#    average_order
# 0       6.367797
# 1       6.367797
# 2       6.367797
# 3       6.367797
# 4       6.367797

# %% [markdown]
# # 4. Create Flag for High and Low Spenders

# %%
# assign flags for low and high spenders
df.loc[df['average_order'] >9.99, 'spender'] = 'High Spender'
df.loc[df['average_order'] <9.99, 'spender'] = 'Low Spender'

# %%
# check output 

df.head(100)
# Out:
#      order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0           1.0                2.0                8.0
# 1   2398795.0      1.0           2.0                3.0                7.0
# 2    473747.0      1.0           3.0                3.0               12.0
# 3   2254736.0      1.0           4.0                4.0                7.0
# 4    431534.0      1.0           5.0                4.0               15.0
# ..        ...      ...           ...                ...                ...
# 95  3226575.0    360.0           1.0                5.0               12.0
# 96  1469869.0    377.0           3.0                5.0               17.0
# 97  1927023.0    387.0           2.0                4.0               10.0
# 98   858092.0    420.0           4.0                1.0               19.0
# 99   119314.0    420.0           5.0                3.0               19.0
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN       196.0                1.0        0.0   both
# 1                     15.0       196.0                1.0        1.0   both
# 2                     21.0       196.0                1.0        1.0   both
# 3                     29.0       196.0                1.0        1.0   both
# 4                     28.0       196.0                1.0        1.0   both
# ..                     ...         ...                ...        ...    ...
# 95                     NaN       196.0                1.0        0.0   both
# 96                     3.0       196.0                9.0        0.0   both
# 97                    22.0       196.0                3.0        0.0   both
# 98                    30.0       196.0                2.0        0.0   both
# 99                    16.0       196.0                2.0        1.0   both
#
#     ... department_id  prices    price_range_loc     busiest_days  \
# 0   ...           7.0     9.0  Mid=range product   Regularly busy
# 1   ...           7.0     9.0  Mid=range product  Least busy days
# 2   ...           7.0     9.0  Mid=range product  Least busy days
# 3   ...           7.0     9.0  Mid=range product  Least busy days
# 4   ...           7.0     9.0  Mid=range product  Least busy days
# ..  ...           ...     ...                ...              ...
# 95  ...           7.0     9.0  Mid=range product   Regularly busy
# 96  ...           7.0     9.0  Mid=range product   Regularly busy
# 97  ...           7.0     9.0  Mid=range product  Least busy days
# 98  ...           7.0     9.0  Mid=range product     Busiest days
# 99  ...           7.0     9.0  Mid=range product  Least busy days
#
#    busiest_period_of_day  max_order      loyalty_flag  averge_order  \
# 0         Average Orders   6.367797  Regular customer      6.367797
# 1         Average Orders   6.367797  Regular customer      6.367797
# 2            Most Orders   6.367797  Regular customer      6.367797
# 3         Average Orders   6.367797  Regular customer      6.367797
# 4            Most Orders   6.367797  Regular customer      6.367797
# ..                   ...        ...               ...           ...
# 95           Most Orders  10.006250      New customer     10.006250
# 96        Average Orders   8.496552      New customer      8.496552
# 97           Most Orders   7.396610      New customer      7.396610
# 98        Average Orders   7.387805  Regular customer      7.387805
# 99        Average Orders   7.387805  Regular customer      7.387805
#
#    average_order       spender
# 0       6.367797   Low Spender
# 1       6.367797   Low Spender
# 2       6.367797   Low Spender
# 3       6.367797   Low Spender
# 4       6.367797   Low Spender
# ..           ...           ...
# 95     10.006250  High Spender
# 96      8.496552   Low Spender
# 97      7.396610   Low Spender
# 98      7.387805   Low Spender
# 99      7.387805   Low Spender
#
# [100 rows x 22 columns]

# %%
# calculate the median for days_since_prior_order
df['median_frequency'] = df.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# create flag for days_since_prior_order for frequency
df.loc[df['median_frequency'] > 19, 'frequency'] = 'Non Frequent'

# %%
df.loc[(df['median_frequency'] <= 19) & (df['median_frequency'] > 10), 'frequency'] = 'Regular Customer'

# %%
df.loc[df['median_frequency'] <= 9, 'frequency'] = 'Frequent Customer'

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_range_loc', 'busiest_days',
#        'busiest_period_of_day', 'max_order', 'loyalty_flag', 'averge_order',
#        'average_order', 'spender', 'frequency', 'median_frequency'],
#       dtype='object')

# %%
df.head()
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                2.0                8.0
# 1  2398795.0      1.0           2.0                3.0                7.0
# 2   473747.0      1.0           3.0                3.0               12.0
# 3  2254736.0      1.0           4.0                4.0                7.0
# 4   431534.0      1.0           5.0                4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN       196.0                1.0        0.0   both
# 1                    15.0       196.0                1.0        1.0   both
# 2                    21.0       196.0                1.0        1.0   both
# 3                    29.0       196.0                1.0        1.0   both
# 4                    28.0       196.0                1.0        1.0   both
#
#    ...    price_range_loc     busiest_days  busiest_period_of_day  max_order  \
# 0  ...  Mid=range product   Regularly busy         Average Orders   6.367797
# 1  ...  Mid=range product  Least busy days         Average Orders   6.367797
# 2  ...  Mid=range product  Least busy days            Most Orders   6.367797
# 3  ...  Mid=range product  Least busy days         Average Orders   6.367797
# 4  ...  Mid=range product  Least busy days            Most Orders   6.367797
#
#        loyalty_flag averge_order average_order      spender     frequency  \
# 0  Regular customer     6.367797      6.367797  Low Spender  Non Frequent
# 1  Regular customer     6.367797      6.367797  Low Spender  Non Frequent
# 2  Regular customer     6.367797      6.367797  Low Spender  Non Frequent
# 3  Regular customer     6.367797      6.367797  Low Spender  Non Frequent
# 4  Regular customer     6.367797      6.367797  Low Spender  Non Frequent
#
#    median_frequency
# 0              20.0
# 1              20.0
# 2              20.0
# 3              20.0
# 4              20.0
#
# [5 rows x 24 columns]

# %% [markdown]
# I'm not sure how I got two average order columns. There was a lot going on in this code. Also I'm curious as to why my markdowns have two different foints going on. Some look more like coding and some look more like the output, but I'm not selecting anything differently consciously.

# %% [markdown]
# # 5. Export Data

# %%
#export to pickle

df.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_large_4_8.pkl'))

# %%
df['loyalty_flag'].value_counts()
# Out:
# Regular customer    16381472
# Loyal customer      10679578
# New customer         5580218
# Name: loyalty_flag, dtype: int64

# %%
df.shape
# Out:
# (32641279, 21)
